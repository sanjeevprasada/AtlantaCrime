# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import datetime

# %% [markdown]
# ## Date & Time Functions

# %%
# def occurence_time(row):
#     if row['OccurTime'] < 800:
#         return "Morning"
#     elif row['OccurTime'] < 1600:
#         return "Day"
#     else:
#         return "Evening"

def print_month(row):
    cur_date = row['Date']
    month, day, year = (int(x) for x in cur_date.split('/'))    
    month = int(month)
    return month

def day_of_month(row):
    cur_date = row['Date']
    month, day, year = (int(x) for x in cur_date.split('/'))    
    day = int(day)
    return day

def year(row):
    cur_date = row['Date']
    month, day, year = (int(x) for x in cur_date.split('/'))    
    year = int(year)
    return year

def day_of_week(row):
    cur_date = row['Date']
    month, day, year = (int(x) for x in cur_date.split('/'))    
    dt = datetime.date(year, month, day)
    return(dt.weekday())

# %% [markdown]
# # Manipulate and Export

# %%
file = open('bigdaddy.txt','r').read()
user_dict = eval(file)

data = pd.DataFrame.from_dict({(i,j): user_dict[i][j]
                           for i in user_dict.keys() 
                           for j in user_dict[i].keys()},
                       orient='index')

data.reset_index(inplace=True)

#Turn index tuple into 2 features
new_col_list = ['Neighborhood','Date']
for n,col in enumerate(new_col_list):
    data[col] = data['index'].apply(lambda cat: cat[n])
data = data.drop('index',axis=1)

#rename features
print(data.columns)
data.rename(columns={0: 'Category 1', 1: 'Category 2',
                     2: 'Category 3',3: 'Category 4'}, inplace=True)

#Extract date features
data['Year'] = data.apply(lambda row: year(row), axis=1)
data['Month'] = data.apply(lambda row: print_month(row), axis=1)
data['Day of Month'] = data.apply(lambda row: day_of_month(row), axis=1)
data['Day of Week'] = data.apply(lambda row: day_of_week(row), axis=1)
#data['Shift Occurence'] = data.apply (lambda row: occurence_time(row),axis=1)

#Reorder Columns
data = data[['Neighborhood','Date','Year','Month','Day of Month','Day of Week'
             ,'Category 1', 'Category 2', 'Category 3', 'Category 4']]
#Export
#data.to_csv("cobra-counts2019.csv", index=False)
print(data.columns.values)
data
# Out:
# Index([0, 1, 2, 3, 'Neighborhood', 'Date'], dtype='object')
# ['Neighborhood' 'Date' 'Year' 'Month' 'Day of Month' 'Day of Week'
#  'Category 1' 'Category 2' 'Category 3' 'Category 4']
#        Neighborhood     Date  Year  Month  Day of Month  Day of Week  \
# 0          Downtown   1/1/19    19      1             1            1
# 1          Downtown   1/2/19    19      1             2            2
# 2          Downtown   1/3/19    19      1             3            3
# 3          Downtown   1/4/19    19      1             4            4
# 4          Downtown   1/5/19    19      1             5            5
# 5          Downtown   1/6/19    19      1             6            6
# 6          Downtown   1/7/19    19      1             7            0
# 7          Downtown   1/8/19    19      1             8            1
# 8          Downtown   1/9/19    19      1             9            2
# 9          Downtown  1/10/19    19      1            10            3
# 10         Downtown  1/11/19    19      1            11            4
# 11         Downtown  1/12/19    19      1            12            5
# 12         Downtown  1/13/19    19      1            13            6
# 13         Downtown  1/14/19    19      1            14            0
# 14         Downtown  1/15/19    19      1            15            1
# 15         Downtown  1/16/19    19      1            16            2
# 16         Downtown  1/17/19    19      1            17            3
# 17         Downtown  1/18/19    19      1            18            4
# 18         Downtown  1/19/19    19      1            19            5
# 19         Downtown  1/20/19    19      1            20            6
# 20         Downtown  1/21/19    19      1            21            0
# 21         Downtown  1/22/19    19      1            22            1
# 22         Downtown  1/23/19    19      1            23            2
# 23         Downtown  1/24/19    19      1            24            3
# 24         Downtown  1/25/19    19      1            25            4
# 25         Downtown  1/26/19    19      1            26            5
# 26         Downtown  1/27/19    19      1            27            6
# 27         Downtown  1/28/19    19      1            28            0
# 28         Downtown  1/29/19    19      1            29            1
# 29         Downtown  1/30/19    19      1            30            2
