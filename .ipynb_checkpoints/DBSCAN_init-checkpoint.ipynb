# %%
import sklearn as sk
from sklearn import cluster
import numpy as np
import sys
import pandas as pd

data = pd.read_csv("COBRA-2019.csv", sep=',', header=0, engine='python', usecols = lambda column : column in ["Latitude", "Longitude"])
X = data.as_matrix()
#print(X)
db = sk.cluster.DBSCAN(eps=0.3, min_samples=10).fit(X)
#core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
#core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_

# Number of clusters in labels
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0) 

print(labels)

import matplotlib.pyplot as plt

unique_labels = set(labels)
colors = ['y', 'b', 'g', 'r']
print(colors)

for k, col in zip(unique_labels, colors): 
    if k == -1: 
        # Black used for noise. 
        col = 'k'
    class_member_mask = (labels == k) 
  
    xy = X[class_member_mask & core_samples_mask] 
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=col, 
                                      markeredgecolor='k',  
                                      markersize=6) 
  
    xy = X[class_member_mask & ~core_samples_mask] 
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=col, 
                                      markeredgecolor='k', 
                                      markersize=6) 
  
plt.title('number of clusters: %d' %n_clusters_) 
plt.show()
# Out:
# C:\Users\Gabe\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# [0 0 0 ... 0 0 0]
# ['y', 'b', 'g', 'r']

# %%
print(labels)
print(np.unique(labels))
# Out:
# [0 0 0 ... 0 0 0]
# [0]
