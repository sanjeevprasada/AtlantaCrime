# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import datetime

# %% [markdown]
# ## Date & Time Functions

# %%
# def occurence_time(row):
#     if row['OccurTime'] < 800:
#         return "Morning"
#     elif row['OccurTime'] < 1600:
#         return "Day"
#     else:
#         return "Evening"

def print_month(row):
    cur_date = row['Date']
    month, day, year = (int(x) for x in cur_date.split('/'))    
    month = int(month)
    return month

def day_of_month(row):
    cur_date = row['Date']
    month, day, year = (int(x) for x in cur_date.split('/'))    
    day = int(day)
    return day

def year(row):
    cur_date = row['Date']
    month, day, year = (int(x) for x in cur_date.split('/'))    
    year = int(year)
    return year

def day_of_week(row):
    cur_date = row['Date']
    month, day, year = (int(x) for x in cur_date.split('/'))    
    dt = datetime.date(year, month, day)
    return(dt.weekday())

# %% [markdown]
# # Manipulate and Export

# %%
file = open('generalized2019.txt','r').read()
user_dict = eval(file)

data = pd.DataFrame.from_dict(user_dict,orient='index')
data.reset_index(inplace=True)

#rename features
print(data.columns)
data.rename(columns={'index': 'Date', 0: 'Category 1', 1: 'Category 2',
                     2: 'Category 3',3: 'Category 4'}, inplace=True)

#Extract date features
data['Year'] = data.apply(lambda row: year(row), axis=1)
data['Month'] = data.apply(lambda row: print_month(row), axis=1)
data['Day of Month'] = data.apply(lambda row: day_of_month(row), axis=1)
data['Day of Week'] = data.apply(lambda row: day_of_week(row), axis=1)
#data['Shift Occurence'] = data.apply (lambda row: occurence_time(row),axis=1)

#Reorder Columns
data = data[['Date','Year','Month','Day of Month','Day of Week'
             ,'Category 1', 'Category 2', 'Category 3', 'Category 4']]
#Export
data.to_csv("cobra-generalized2019.csv", index=False)
print(data.columns.values)
data
# Out:
# Index(['index', 0, 1, 2, 3], dtype='object')
# ['Date' 'Year' 'Month' 'Day of Month' 'Day of Week' 'Category 1'
#  'Category 2' 'Category 3' 'Category 4']
#         Date  Year  Month  Day of Month  Day of Week  Category 1  Category 2  \
# 0     1/1/19    19      1             1            1           0           9
# 1    1/10/19    19      1            10            3           2           4
# 2    1/11/19    19      1            11            4           0           7
# 3    1/12/19    19      1            12            5           1           5
# 4    1/13/19    19      1            13            6           0           7
# 5    1/14/19    19      1            14            0           1          11
# 6    1/15/19    19      1            15            1           0           3
# 7    1/16/19    19      1            16            2           1           4
# 8    1/17/19    19      1            17            3           0           6
# 9    1/18/19    19      1            18            4           0           4
# 10   1/19/19    19      1            19            5           1           2
# 11    1/2/19    19      1             2            2           0           7
# 12   1/20/19    19      1            20            6           0           2
# 13   1/21/19    19      1            21            0           0           8
# 14   1/22/19    19      1            22            1           0           3
# 15   1/23/19    19      1            23            2           0           5
# 16   1/24/19    19      1            24            3           0           6
# 17   1/25/19    19      1            25            4           0           3
# 18   1/26/19    19      1            26            5           0           7
# 19   1/27/19    19      1            27            6           0           3
# 20   1/28/19    19      1            28            0           0           6
# 21   1/29/19    19      1            29            1           0           2
# 22    1/3/19    19      1             3            3           1           5
# 23   1/30/19    19      1            30            2           0           6
# 24   1/31/19    19      1            31            3           1           6
# 25    1/4/19    19      1             4            4           1           9
# 26    1/5/19    19      1             5            5           0           8
# 27    1/6/19    19      1             6            6           0           6
# 28    1/7/19    19      1             7            0           0          10
# 29    1/8/19    19      1             8            1           0           4
# ..       ...   ...    ...           ...          ...         ...         ...
# 236  8/31/19    19      8            31            5           0           9
# 237   8/4/19    19      8             4            6           1          12
# 238   8/5/19    19      8             5            0           0           7
# 239   8/6/19    19      8             6            1           0           9
# 240   8/7/19    19      8             7            2           0           8
# 241   8/8/19    19      8             8            3           1           5
# 242   8/9/19    19      8             9            4           0           7
# 243   9/1/19    19      9             1            6           0           5
# 244  9/10/19    19      9            10            1           0           9
# 245  9/11/19    19      9            11            2           0           6
# 246  9/12/19    19      9            12            3           0           5
# 247  9/13/19    19      9            13            4           0           8
# 248  9/14/19    19      9            14            5           0           7
# 249  9/15/19    19      9            15            6           0           9
# 250  9/16/19    19      9            16            0           0           4
# 251  9/17/19    19      9            17            1           0           9
# 252  9/18/19    19      9            18            2           0           4
# 253  9/19/19    19      9            19            3           0           4
# 254   9/2/19    19      9             2            0           0           6
# 255  9/20/19    19      9            20            4           1           7
# 256  9/21/19    19      9            21            5           0           9
# 257  9/22/19    19      9            22            6           0          11
# 258  9/23/19    19      9            23            0           0           0
# 259   9/3/19    19      9             3            1           0           7
# 260   9/4/19    19      9             4            2           0           6
# 261   9/5/19    19      9             5            3           0           9
# 262   9/6/19    19      9             6            4           1          10
# 263   9/7/19    19      9             7            5           0           6
# 264   9/8/19    19      9             8            6           1           4
# 265   9/9/19    19      9             9            0           0           4
#
#      Category 3  Category 4
# 0            15          36
# 1            14          35
# 2            13          53
# 3             5          45
# 4            14          27
# 5            23          48
# 6            14          30
# 7            18          40
# 8            11          51
# 9            13          45
# 10           16          46
# 11           13          33
# 12           17          30
# 13           16          50
# 14           16          51
# 15           14          26
# 16           15          31
# 17           24          34
# 18           19          33
# 19            5          26
# 20           15          30
# 21           20          26
# 22           15          42
# 23           20          28
# 24           16          30
# 25           11          54
# 26           12          35
# 27           10          30
# 28           15          42
# 29           17          37
# ..          ...         ...
# 236          23          43
# 237          16          45
# 238          11          47
# 239          14          46
# 240          14          53
# 241          18          41
# 242          22          54
# 243          16          45
# 244          11          28
# 245          22          52
# 246          16          50
# 247           9          45
# 248          16          38
# 249          12          43
# 250           7          38
# 251          16          36
# 252          14          51
# 253          12          43
# 254          12          40
# 255          18          60
# 256          13          57
# 257          14          48
# 258           3          10
# 259          10          30
# 260          14          43
# 261          12          51
# 262          16          54
# 263          17          50
# 264          10          34
# 265          14          43
#
# [266 rows x 9 columns]
